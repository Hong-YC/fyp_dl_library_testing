# %%
# %run torch_model.py
# Out:
# 00_input_object: (None, 27, 6, 64)
# 01_Conv2d: (None, 37, 1, 59)
# 02_Conv2d: (None, 63, 1, 3)
# 03_Flatten: (None, 189)
# 04_Linear: (None, 12)
# 05_reshape: (None, 3, 4)
# ...
